# %% [markdown]
# # Automated Brain Tumor Detection Using Deep Learning Techniques (CNN)

# %% [markdown]
# Introduction:
#
# Brain tumors represent a major global health concern, affecting both children and adults. Early and accurate diagnosis plays a crucial role in treatment planning and improving patient outcomes. Magnetic Resonance Imaging (MRI) is the primary imaging modality for detecting brain tumors, producing large volumes of image data that require careful analysis by radiologists. However, manual examination is prone to errors due to the complexity and variability of brain tumors.
#
# This project proposes the development of an automated system for brain tumor classification using Convolutional Neural Networks (CNNs).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import packages

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

plt.style.use('seaborn-v0_8')


from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import random
from PIL import Image
import glob
import seaborn as sns
from tqdm.notebook import tqdm
import time

from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_curve,auc, accuracy_score, confusion_matrix, classification_report

import tensorflow
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %% [markdown]
# # Load Visualization

# %%
train_path = "/content/drive/MyDrive/Brain-Tumor-Classification-DataSet-master/Testing"
test_path = "/content/drive/MyDrive/Brain-Tumor-Classification-DataSet-master/Training"

classes = ['no_tumor','pituitary_tumor', 'meningioma_tumor','glioma_tumor']
#classes.index('no_tumor')

X_train = []
Y_train = []
# Function to load images and assign a class
def load_data(directory):
    for class_name in tqdm(os.listdir(directory),desc=directory):
        class_path = os.path.join(directory, class_name)
        class_label = class_name
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = cv2.imread(image_path)
            X_train.append(img)
            Y_train.append(classes.index(class_name))
    return X_train,Y_train

X_train , Y_train = load_data(train_path)
X_train , Y_train = load_data(test_path)
# Out:
# /content/drive/MyDrive/Brain-Tumor-Classification-DataSet-master/Testing:   0%|          | 0/4 [00:00<?, ?it/s…
# /content/drive/MyDrive/Brain-Tumor-Classification-DataSet-master/Training:   0%|          | 0/4 [00:00<?, ?it/…

# %% [markdown]
# # Data Visualization

# %%
# Function to count the number of images per class
def count_images_per_class(data, classes):
    count_per_class = {class_name: 0 for class_name in classes}
    for class_idx in data:
        class_name = classes[class_idx]
        count_per_class[class_name] += 1
    return count_per_class

# Count the number of images per class for the training and test sets
train_count_per_class = count_images_per_class(Y_train, classes)

plt.figure(figsize=(8, 5))
# Training data
train_bars = plt.bar(train_count_per_class.keys(), train_count_per_class.values(), color='#4C72B0')
plt.title('Image distribution per class (Training)')
plt.xlabel('Classes')
plt.ylabel('Number of images')

# Add percentages
for bar in train_bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height,
             f'{height} ({height / np.sum(list(train_count_per_class.values())) * 100:.1f}%)',
             ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# # Examples of images for each class

# %%
def show_examples(X_data, Y_data, classes, num_examples=5):
    num_classes = len(classes)
    fig, axs = plt.subplots(num_classes, num_examples, figsize=(10, 8))

    for i, class_name in enumerate(classes):
        class_indices = [idx for idx, label in enumerate(Y_data) if label == i]
        axs[i, 0].set_title(class_name, fontsize=10, pad=10, fontweight='bold')
        for j in range(num_examples):
                img = X_data[class_indices[j]]
                axs[i, j].imshow(img)
                axs[i, j].axis('off')

    plt.tight_layout()
    plt.show()

show_examples(X_train, Y_train, classes)

# %% [markdown]
# # Most common image size

# %%
# Most frequent image sizes:
train_data_shapes = []
for img in X_train:
    train_data_shapes.append(img.shape)

# Count occurrences for each size
shape_counts = {}
for shape in train_data_shapes:
    if shape not in shape_counts:
        shape_counts[shape] = 0
    shape_counts[shape] += 1

# Sort the shapes by count
sorted_shapes = sorted(shape_counts.items(), key=lambda x: x[1], reverse=True)

# Display the most frequent image sizes
print("Most frequent train image shapes:")
for shape, count in sorted_shapes[:3]:
    print(f"- {shape}: {count}")
# Out:
# Most frequent train image shapes:
# - (512, 512, 3): 2341
# - (236, 236, 3): 79
# - (225, 225, 3): 43

# %% [markdown]
# Most images have a high resolution of 512×512 pixels. This high resolution can lead to longer processing times and increased memory usage. Therefore, to optimize model performance while maintaining adequate image quality, a lower resolution of 225×225 pixels is preferred.

# %%
shape = (225, 225, 3)

# %% [markdown]
# # Data preparation

# %%
# Function to crop an image
def crop_image(image):
    # Convert the image to grayscale
    if len(image.shape) == 3:  # Check if the image is in BGR format
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:  # Image is already in grayscale
        gray = image.copy()

    # Threshold the image
    _, thresh = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)

    # Find contours in the image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Find the largest contour
    largest_contour = max(contours, key=cv2.contourArea)

    # Crop the image to the largest contour
    cropped_image = image[
        cv2.boundingRect(largest_contour)[1] : cv2.boundingRect(largest_contour)[1] + cv2.boundingRect(largest_contour)[3],
        cv2.boundingRect(largest_contour)[0] : cv2.boundingRect(largest_contour)[0] + cv2.boundingRect(largest_contour)[2]
    ]

    return cropped_image

# %%
image_path = "/content/drive/MyDrive/Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(56).jpg"
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Load and crop the image
cropped_image = crop_image(img)

# Display the original and cropped images
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(cv2.imread(image_path, cv2.IMREAD_GRAYSCALE), cmap='gray')
plt.title("Original Image", fontsize=10)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cropped_image, cmap='gray')
plt.title("Cropped Image (no empty spaces)", fontsize=10)
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Crop, normalize, and resize all images
def preprocess_data(train_data):
    processed_data = []
    for img in tqdm(train_data):

        # Apply cropping
        cropped_img = crop_image(img)

        # Resize the image
        resized_img = cv2.resize(cropped_img, (shape[1], shape[0]))

        # Normalize the image
        # normalized_img = resized_img / 255.0
        normalized_img = cv2.normalize(resized_img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

        # Append the preprocessed image to processed data
        processed_data.append(normalized_img)

    return processed_data

# Preprocess training and test data
X_train = preprocess_data(X_train)

X_train = np.array(X_train)
# Out:
#   0%|          | 0/3264 [00:00<?, ?it/s]

# %%
# Function to display example images for each class after preprocessing
def show_examples(X_data, Y_data, classes, num_examples=5):
    num_classes = len(classes)
    fig, axs = plt.subplots(num_classes, num_examples, figsize=(10, 8))

    for i, class_name in enumerate(classes):
        class_indices = [idx for idx, label in enumerate(Y_data) if label == i]
        axs[i, 0].set_title(class_name, fontsize=10, pad=10, fontweight='bold')
        for j in range(num_examples):
            img = X_data[class_indices[j]]
            axs[i, j].imshow(img)
            axs[i, j].axis('off')

    plt.tight_layout()
    plt.show()

# Display example images for each class after preprocessing
show_examples(X_train, Y_train, classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-9.313226e-10..1.0].

# %%
X_train, Y_train = shuffle(X_train,Y_train, random_state=64)
X_train,X_test,Y_train,Y_test = train_test_split(X_train,Y_train, test_size=0.3,random_state=64)
X_test,X_val,Y_test,Y_val = train_test_split(X_test,Y_test, test_size=2/3,random_state=64)

# %%
sizes = [len(Y_train), len(Y_val), len(Y_test)]
labels = ['Training', 'Validation', 'Test']
colors = ['#4285f4', '#E17A8A', '#fbbc05']

plt.figure(figsize=(6,3))
plt.rcParams.update({'font.size': 8})
patches, texts, autotexts = plt.pie(
    sizes,
    labels=labels,
    colors=colors,
    autopct='%.1f%%',
    explode=(0.1, 0.08, 0.08),
    shadow=True,
    startangle=60
)
plt.title("Distribution of Training, Validation, and Test Images")
plt.legend(
    patches,
    [f"{label} : {size}" for label, size in zip(labels, sizes)],
    loc="upper left",
    bbox_to_anchor=(-0.1, 1)  # Décale la légende plus à gauche
)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
Y_train =  np.array(tensorflow.keras.utils.to_categorical(Y_train))
Y_val =  np.array(tensorflow.keras.utils.to_categorical(Y_val))
Y_test =  np.array(tensorflow.keras.utils.to_categorical(Y_test))

train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.,
    height_shift_range=0.,
    shear_range=0.2,
    zoom_range=0.05,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest'
)

train_generator = train_datagen.flow(
    x=np.array(X_train),
    y=np.array(Y_train)
)

# %%
random_index = np.random.randint(len(X_train))
image = X_train[random_index]
class_label_encoded = Y_train[random_index]
class_label = classes[np.argmax(class_label_encoded)]

# Display the original image
plt.figure(figsize=(10, 5))
plt.subplot(1, 5, 1)
plt.imshow(image)
plt.title('Original\n({})'.format(class_label), fontsize=8)
plt.axis('off')

# Generate and display augmented versions of the image
for i in range(4):
    augmented_image = train_datagen.random_transform(image)
    plt.subplot(1, 5, i + 2)
    plt.imshow(augmented_image)
    plt.title('Augmented {}'.format(i + 1), fontsize=8)
    plt.axis('off')

plt.show()

# %% [markdown]
# # Modelisation

# %%
CNN_model = Sequential()
CNN_model.add(Conv2D(16, (3,3), activation='relu', input_shape=shape))
CNN_model.add(MaxPooling2D(2,2))
CNN_model.add(Dropout(0.2))

CNN_model.add(Conv2D(32, (3,3), activation='relu'))
CNN_model.add(MaxPooling2D(2,2))
CNN_model.add(Dropout(0.2))

CNN_model.add(Conv2D(64, (3,3), activation='relu'))
CNN_model.add(MaxPooling2D(2,2))
CNN_model.add(Dropout(0.2))

CNN_model.add(Conv2D(128, (3,3), activation='relu'))
CNN_model.add(MaxPooling2D(2,2))
CNN_model.add(Dropout(0.2))

CNN_model.add(Conv2D(512, (3,3), activation='relu'))
CNN_model.add(MaxPooling2D(2,2))
CNN_model.add(Dropout(0.2))

CNN_model.add(Flatten())
CNN_model.add(Dense(512, activation='relu'))
CNN_model.add(Dropout(0.5))

CNN_model.add(Dense(len(classes), activation='softmax'))


CNN_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Precision(), Recall()])
CNN_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 223, 223, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 111, 111, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 26, 26, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 10, 10, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 5, 5, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 5, 5, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     6,554,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,243,940 (27.63 MB)
#  Trainable params: 7,243,940 (27.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
tensorflow.keras.utils.plot_model(CNN_model,show_shapes=True, show_layer_names=True, dpi=50)

# %%
# Define batch size
batch_size = 64

# Image shape: height, width, RGB
image_shape = shape

# Number of epochs
epochs = 80

print(f'Batch size: {batch_size}')
print(f'Image shape: {image_shape}')
print(f'Number of epochs: {epochs}')
# Out:
# Batch size: 64
# Image shape: (225, 225, 3)
# Number of epochs: 80

# %%
# Add ReduceLROnPlateau, EarlyStopping, and ModelCheckpoint as callbacks during training
reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',  # metric to monitor
    factor=0.1,              # factor to reduce learning rate
    patience=10,             # number of epochs with no improvement before reducing LR
    min_delta=0.0001,        # minimum change to qualify as improvement
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',      # metric to monitor
    patience=15,             # number of epochs with no improvement before stopping
    restore_best_weights=True,  # restore the best model weights
    verbose=1
)  # Stops training early if validation performance doesn't improve over a number of epochs

checkpoint = ModelCheckpoint(
    filepath='best_CNNModel.keras',  # file path to save the model
    monitor='val_accuracy',          # metric to monitor
    save_best_only=True,             # save only the best model
    verbose=1
)  # Saves the best model based on validation performance

# %%
import time
# Train the model
start_time = time.time()
CNN_history = CNN_model.fit(
    train_generator,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_val, Y_val),
    callbacks=[reduce_lr, early_stop, checkpoint],
    verbose=1
)
end_time = time.time()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2790 - loss: 1.3758 - precision: 0.5079 - recall: 0.0297
# Epoch 1: val_accuracy improved from -inf to 0.26606, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - accuracy: 0.2791 - loss: 1.3757 - precision: 0.5080 - recall: 0.0294 - val_accuracy: 0.2661 - val_loss: 1.3932 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3441 - loss: 1.2854 - precision: 0.4236 - recall: 0.0253
# Epoch 2: val_accuracy improved from 0.26606 to 0.29511, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.3442 - loss: 1.2852 - precision: 0.4246 - recall: 0.0254 - val_accuracy: 0.2951 - val_loss: 1.5572 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3806 - loss: 1.2160 - precision: 0.5080 - recall: 0.0405
# Epoch 3: val_accuracy did not improve from 0.29511
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - accuracy: 0.3810 - loss: 1.2158 - precision: 0.5081 - recall: 0.0408 - val_accuracy: 0.2890 - val_loss: 1.4736 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4796 - loss: 1.1764 - precision: 0.4746 - recall: 0.0817
# Epoch 4: val_accuracy improved from 0.29511 to 0.35168, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.4795 - loss: 1.1762 - precision: 0.4754 - recall: 0.0821 - val_accuracy: 0.3517 - val_loss: 1.4049 - val_precision: 0.4886 - val_recall: 0.0657 - learning_rate: 0.0010
# Epoch 5/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4999 - loss: 1.1173 - precision: 0.5992 - recall: 0.2074
# Epoch 5: val_accuracy did not improve from 0.35168
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.5002 - loss: 1.1168 - precision: 0.5994 - recall: 0.2081 - val_accuracy: 0.3410 - val_loss: 1.5311 - val_precision: 0.3624 - val_recall: 0.2920 - learning_rate: 0.0010
# Epoch 6/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5761 - loss: 1.0030 - precision: 0.6419 - recall: 0.3775
# Epoch 6: val_accuracy improved from 0.35168 to 0.48012, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.5761 - loss: 1.0028 - precision: 0.6420 - recall: 0.3777 - val_accuracy: 0.4801 - val_loss: 1.2431 - val_precision: 0.4951 - val_recall: 0.3853 - learning_rate: 0.0010
# Epoch 7/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6199 - loss: 0.8952 - precision: 0.6959 - recall: 0.4800
# Epoch 7: val_accuracy improved from 0.48012 to 0.62844, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - accuracy: 0.6202 - loss: 0.8947 - precision: 0.6960 - recall: 0.4806 - val_accuracy: 0.6284 - val_loss: 1.0102 - val_precision: 0.6673 - val_recall: 0.5642 - learning_rate: 0.0010
# Epoch 8/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6615 - loss: 0.8238 - precision: 0.7126 - recall: 0.5587
# Epoch 8: val_accuracy did not improve from 0.62844
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 198s 3s/step - accuracy: 0.6616 - loss: 0.8235 - precision: 0.7128 - recall: 0.5590 - val_accuracy: 0.5306 - val_loss: 1.3247 - val_precision: 0.5588 - val_recall: 0.4725 - learning_rate: 0.0010
# Epoch 9/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6839 - loss: 0.7646 - precision: 0.7366 - recall: 0.5979
# Epoch 9: val_accuracy did not improve from 0.62844
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.6840 - loss: 0.7642 - precision: 0.7367 - recall: 0.5981 - val_accuracy: 0.5765 - val_loss: 1.1184 - val_precision: 0.6098 - val_recall: 0.5306 - learning_rate: 0.0010
# Epoch 10/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7189 - loss: 0.6890 - precision: 0.7538 - recall: 0.6553
# Epoch 10: val_accuracy improved from 0.62844 to 0.67431, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.7190 - loss: 0.6888 - precision: 0.7540 - recall: 0.6554 - val_accuracy: 0.6743 - val_loss: 0.8608 - val_precision: 0.7101 - val_recall: 0.6254 - learning_rate: 0.0010
# Epoch 11/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7642 - loss: 0.6148 - precision: 0.8030 - recall: 0.7137
# Epoch 11: val_accuracy did not improve from 0.67431
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 201s 3s/step - accuracy: 0.7641 - loss: 0.6149 - precision: 0.8029 - recall: 0.7136 - val_accuracy: 0.6300 - val_loss: 1.1539 - val_precision: 0.6546 - val_recall: 0.6086 - learning_rate: 0.0010
# Epoch 12/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7550 - loss: 0.5867 - precision: 0.7992 - recall: 0.7110
# Epoch 12: val_accuracy did not improve from 0.67431
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.7551 - loss: 0.5868 - precision: 0.7992 - recall: 0.7110 - val_accuracy: 0.6682 - val_loss: 0.8983 - val_precision: 0.6928 - val_recall: 0.6208 - learning_rate: 0.0010
# Epoch 13/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7858 - loss: 0.5695 - precision: 0.8210 - recall: 0.7286
# Epoch 13: val_accuracy improved from 0.67431 to 0.72018, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.7857 - loss: 0.5692 - precision: 0.8210 - recall: 0.7287 - val_accuracy: 0.7202 - val_loss: 0.8110 - val_precision: 0.7471 - val_recall: 0.6911 - learning_rate: 0.0010
# Epoch 14/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7826 - loss: 0.5243 - precision: 0.8129 - recall: 0.7384
# Epoch 14: val_accuracy did not improve from 0.72018
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.7828 - loss: 0.5242 - precision: 0.8131 - recall: 0.7386 - val_accuracy: 0.7034 - val_loss: 0.8849 - val_precision: 0.7264 - val_recall: 0.6820 - learning_rate: 0.0010
# Epoch 15/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8228 - loss: 0.4466 - precision: 0.8498 - recall: 0.7924
# Epoch 15: val_accuracy improved from 0.72018 to 0.77676, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.8227 - loss: 0.4467 - precision: 0.8497 - recall: 0.7924 - val_accuracy: 0.7768 - val_loss: 0.6123 - val_precision: 0.8047 - val_recall: 0.7370 - learning_rate: 0.0010
# Epoch 16/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8406 - loss: 0.4346 - precision: 0.8715 - recall: 0.8055
# Epoch 16: val_accuracy did not improve from 0.77676
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.8405 - loss: 0.4347 - precision: 0.8714 - recall: 0.8054 - val_accuracy: 0.7752 - val_loss: 0.6354 - val_precision: 0.7993 - val_recall: 0.7492 - learning_rate: 0.0010
# Epoch 17/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8491 - loss: 0.4031 - precision: 0.8715 - recall: 0.8294
# Epoch 17: val_accuracy did not improve from 0.77676
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.8490 - loss: 0.4033 - precision: 0.8713 - recall: 0.8292 - val_accuracy: 0.7049 - val_loss: 0.8552 - val_precision: 0.7330 - val_recall: 0.6927 - learning_rate: 0.0010
# Epoch 18/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8317 - loss: 0.4903 - precision: 0.8542 - recall: 0.7898
# Epoch 18: val_accuracy improved from 0.77676 to 0.81498, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.8319 - loss: 0.4894 - precision: 0.8543 - recall: 0.7901 - val_accuracy: 0.8150 - val_loss: 0.5073 - val_precision: 0.8522 - val_recall: 0.7844 - learning_rate: 0.0010
# Epoch 19/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8808 - loss: 0.3353 - precision: 0.8924 - recall: 0.8596
# Epoch 19: val_accuracy did not improve from 0.81498
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.8806 - loss: 0.3356 - precision: 0.8923 - recall: 0.8594 - val_accuracy: 0.8104 - val_loss: 0.5508 - val_precision: 0.8177 - val_recall: 0.7752 - learning_rate: 0.0010
# Epoch 20/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8767 - loss: 0.3166 - precision: 0.8982 - recall: 0.8612
# Epoch 20: val_accuracy improved from 0.81498 to 0.82416, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.8767 - loss: 0.3168 - precision: 0.8981 - recall: 0.8612 - val_accuracy: 0.8242 - val_loss: 0.4633 - val_precision: 0.8519 - val_recall: 0.8089 - learning_rate: 0.0010
# Epoch 21/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8798 - loss: 0.3318 - precision: 0.8939 - recall: 0.8629
# Epoch 21: val_accuracy did not improve from 0.82416
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.8798 - loss: 0.3317 - precision: 0.8940 - recall: 0.8629 - val_accuracy: 0.8196 - val_loss: 0.6017 - val_precision: 0.8279 - val_recall: 0.8089 - learning_rate: 0.0010
# Epoch 22/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8760 - loss: 0.3311 - precision: 0.8856 - recall: 0.8585
# Epoch 22: val_accuracy improved from 0.82416 to 0.84098, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 173s 2s/step - accuracy: 0.8760 - loss: 0.3312 - precision: 0.8856 - recall: 0.8585 - val_accuracy: 0.8410 - val_loss: 0.4862 - val_precision: 0.8540 - val_recall: 0.8226 - learning_rate: 0.0010
# Epoch 23/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8876 - loss: 0.2959 - precision: 0.8943 - recall: 0.8711
# Epoch 23: val_accuracy did not improve from 0.84098
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.8876 - loss: 0.2961 - precision: 0.8943 - recall: 0.8711 - val_accuracy: 0.8226 - val_loss: 0.4994 - val_precision: 0.8375 - val_recall: 0.8119 - learning_rate: 0.0010
# Epoch 24/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9139 - loss: 0.2505 - precision: 0.9242 - recall: 0.9009
# Epoch 24: val_accuracy did not improve from 0.84098
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9138 - loss: 0.2507 - precision: 0.9241 - recall: 0.9007 - val_accuracy: 0.7706 - val_loss: 0.7319 - val_precision: 0.7804 - val_recall: 0.7554 - learning_rate: 0.0010
# Epoch 25/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8945 - loss: 0.2989 - precision: 0.9040 - recall: 0.8793
# Epoch 25: val_accuracy did not improve from 0.84098
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - accuracy: 0.8945 - loss: 0.2988 - precision: 0.9040 - recall: 0.8793 - val_accuracy: 0.8058 - val_loss: 0.6740 - val_precision: 0.8217 - val_recall: 0.7890 - learning_rate: 0.0010
# Epoch 26/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8681 - loss: 0.3738 - precision: 0.8879 - recall: 0.8470
# Epoch 26: val_accuracy improved from 0.84098 to 0.84862, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.8681 - loss: 0.3735 - precision: 0.8879 - recall: 0.8470 - val_accuracy: 0.8486 - val_loss: 0.4110 - val_precision: 0.8648 - val_recall: 0.8410 - learning_rate: 0.0010
# Epoch 27/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9056 - loss: 0.2402 - precision: 0.9165 - recall: 0.8964
# Epoch 27: val_accuracy did not improve from 0.84862
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.9056 - loss: 0.2403 - precision: 0.9165 - recall: 0.8964 - val_accuracy: 0.8364 - val_loss: 0.5017 - val_precision: 0.8460 - val_recall: 0.8318 - learning_rate: 0.0010
# Epoch 28/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9146 - loss: 0.2447 - precision: 0.9227 - recall: 0.9005
# Epoch 28: val_accuracy did not improve from 0.84862
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.9146 - loss: 0.2450 - precision: 0.9227 - recall: 0.9005 - val_accuracy: 0.8379 - val_loss: 0.5019 - val_precision: 0.8546 - val_recall: 0.8180 - learning_rate: 0.0010
# Epoch 29/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9157 - loss: 0.2282 - precision: 0.9245 - recall: 0.9061
# Epoch 29: val_accuracy improved from 0.84862 to 0.86391, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.9158 - loss: 0.2281 - precision: 0.9246 - recall: 0.9061 - val_accuracy: 0.8639 - val_loss: 0.4402 - val_precision: 0.8768 - val_recall: 0.8486 - learning_rate: 0.0010
# Epoch 30/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9108 - loss: 0.2359 - precision: 0.9177 - recall: 0.9009
# Epoch 30: val_accuracy improved from 0.86391 to 0.87615, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.9109 - loss: 0.2358 - precision: 0.9178 - recall: 0.9010 - val_accuracy: 0.8761 - val_loss: 0.4893 - val_precision: 0.8775 - val_recall: 0.8654 - learning_rate: 0.0010
# Epoch 31/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9159 - loss: 0.2234 - precision: 0.9235 - recall: 0.9104
# Epoch 31: val_accuracy improved from 0.87615 to 0.89602, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.9160 - loss: 0.2234 - precision: 0.9236 - recall: 0.9105 - val_accuracy: 0.8960 - val_loss: 0.3355 - val_precision: 0.9019 - val_recall: 0.8853 - learning_rate: 0.0010
# Epoch 32/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9125 - loss: 0.2221 - precision: 0.9215 - recall: 0.9062
# Epoch 32: val_accuracy did not improve from 0.89602
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.9125 - loss: 0.2222 - precision: 0.9215 - recall: 0.9063 - val_accuracy: 0.8639 - val_loss: 0.4966 - val_precision: 0.8690 - val_recall: 0.8517 - learning_rate: 0.0010
# Epoch 33/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9351 - loss: 0.1820 - precision: 0.9377 - recall: 0.9252
# Epoch 33: val_accuracy did not improve from 0.89602
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9351 - loss: 0.1820 - precision: 0.9377 - recall: 0.9252 - val_accuracy: 0.8502 - val_loss: 0.5099 - val_precision: 0.8612 - val_recall: 0.8440 - learning_rate: 0.0010
# Epoch 34/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9328 - loss: 0.1879 - precision: 0.9405 - recall: 0.9281
# Epoch 34: val_accuracy did not improve from 0.89602
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9327 - loss: 0.1882 - precision: 0.9404 - recall: 0.9280 - val_accuracy: 0.8180 - val_loss: 0.6640 - val_precision: 0.8247 - val_recall: 0.8058 - learning_rate: 0.0010
# Epoch 35/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9313 - loss: 0.2024 - precision: 0.9374 - recall: 0.9250
# Epoch 35: val_accuracy did not improve from 0.89602
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.9314 - loss: 0.2023 - precision: 0.9375 - recall: 0.9251 - val_accuracy: 0.8670 - val_loss: 0.5041 - val_precision: 0.8774 - val_recall: 0.8532 - learning_rate: 0.0010
# Epoch 36/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9295 - loss: 0.2041 - precision: 0.9399 - recall: 0.9270
# Epoch 36: val_accuracy did not improve from 0.89602
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.9295 - loss: 0.2040 - precision: 0.9399 - recall: 0.9270 - val_accuracy: 0.8716 - val_loss: 0.4511 - val_precision: 0.8842 - val_recall: 0.8639 - learning_rate: 0.0010
# Epoch 37/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9379 - loss: 0.1737 - precision: 0.9453 - recall: 0.9352
# Epoch 37: val_accuracy improved from 0.89602 to 0.92049, saving model to best_CNNModel.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9379 - loss: 0.1738 - precision: 0.9453 - recall: 0.9351 - val_accuracy: 0.9205 - val_loss: 0.2815 - val_precision: 0.9244 - val_recall: 0.9159 - learning_rate: 0.0010
# Epoch 38/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9371 - loss: 0.1811 - precision: 0.9392 - recall: 0.9269
# Epoch 38: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9372 - loss: 0.1810 - precision: 0.9393 - recall: 0.9270 - val_accuracy: 0.8960 - val_loss: 0.4066 - val_precision: 0.9009 - val_recall: 0.8899 - learning_rate: 0.0010
# Epoch 39/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9306 - loss: 0.1954 - precision: 0.9379 - recall: 0.9230
# Epoch 39: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.9305 - loss: 0.1956 - precision: 0.9378 - recall: 0.9229 - val_accuracy: 0.8807 - val_loss: 0.4267 - val_precision: 0.8877 - val_recall: 0.8700 - learning_rate: 0.0010
# Epoch 40/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9312 - loss: 0.1874 - precision: 0.9378 - recall: 0.9240
# Epoch 40: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.9311 - loss: 0.1875 - precision: 0.9378 - recall: 0.9239 - val_accuracy: 0.8440 - val_loss: 0.5451 - val_precision: 0.8496 - val_recall: 0.8379 - learning_rate: 0.0010
# Epoch 41/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9400 - loss: 0.1656 - precision: 0.9467 - recall: 0.9370
# Epoch 41: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9401 - loss: 0.1654 - precision: 0.9468 - recall: 0.9371 - val_accuracy: 0.8807 - val_loss: 0.4114 - val_precision: 0.8862 - val_recall: 0.8807 - learning_rate: 0.0010
# Epoch 42/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9494 - loss: 0.1411 - precision: 0.9507 - recall: 0.9414
# Epoch 42: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 185s 3s/step - accuracy: 0.9494 - loss: 0.1412 - precision: 0.9507 - recall: 0.9414 - val_accuracy: 0.9098 - val_loss: 0.3537 - val_precision: 0.9145 - val_recall: 0.8991 - learning_rate: 0.0010
# Epoch 43/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9447 - loss: 0.1400 - precision: 0.9466 - recall: 0.9406
# Epoch 43: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9446 - loss: 0.1402 - precision: 0.9465 - recall: 0.9406 - val_accuracy: 0.9098 - val_loss: 0.3246 - val_precision: 0.9133 - val_recall: 0.9021 - learning_rate: 0.0010
# Epoch 44/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9383 - loss: 0.1716 - precision: 0.9425 - recall: 0.9315
# Epoch 44: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.9384 - loss: 0.1714 - precision: 0.9425 - recall: 0.9316 - val_accuracy: 0.9006 - val_loss: 0.3644 - val_precision: 0.9087 - val_recall: 0.8976 - learning_rate: 0.0010
# Epoch 45/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9494 - loss: 0.1347 - precision: 0.9554 - recall: 0.9431
# Epoch 45: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.9493 - loss: 0.1349 - precision: 0.9553 - recall: 0.9431 - val_accuracy: 0.8670 - val_loss: 0.4377 - val_precision: 0.8756 - val_recall: 0.8609 - learning_rate: 0.0010
# Epoch 46/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9541 - loss: 0.1258 - precision: 0.9571 - recall: 0.9495
# Epoch 46: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.9541 - loss: 0.1257 - precision: 0.9571 - recall: 0.9495 - val_accuracy: 0.8960 - val_loss: 0.4301 - val_precision: 0.8960 - val_recall: 0.8960 - learning_rate: 0.0010
# Epoch 47/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9529 - loss: 0.1411 - precision: 0.9557 - recall: 0.9485
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 47: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.9528 - loss: 0.1412 - precision: 0.9557 - recall: 0.9485 - val_accuracy: 0.8639 - val_loss: 0.5092 - val_precision: 0.8700 - val_recall: 0.8593 - learning_rate: 0.0010
# Epoch 48/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9706 - loss: 0.0893 - precision: 0.9727 - recall: 0.9685
# Epoch 48: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9705 - loss: 0.0893 - precision: 0.9727 - recall: 0.9684 - val_accuracy: 0.8884 - val_loss: 0.4202 - val_precision: 0.8904 - val_recall: 0.8823 - learning_rate: 1.0000e-04
# Epoch 49/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9674 - loss: 0.0908 - precision: 0.9683 - recall: 0.9644
# Epoch 49: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.9673 - loss: 0.0910 - precision: 0.9682 - recall: 0.9644 - val_accuracy: 0.8869 - val_loss: 0.4162 - val_precision: 0.8894 - val_recall: 0.8853 - learning_rate: 1.0000e-04
# Epoch 50/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9755 - loss: 0.0757 - precision: 0.9764 - recall: 0.9755
# Epoch 50: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - accuracy: 0.9755 - loss: 0.0758 - precision: 0.9764 - recall: 0.9755 - val_accuracy: 0.8991 - val_loss: 0.3944 - val_precision: 0.9043 - val_recall: 0.8960 - learning_rate: 1.0000e-04
# Epoch 51/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9760 - loss: 0.0730 - precision: 0.9764 - recall: 0.9760
# Epoch 51: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9760 - loss: 0.0731 - precision: 0.9764 - recall: 0.9760 - val_accuracy: 0.8930 - val_loss: 0.4129 - val_precision: 0.8995 - val_recall: 0.8899 - learning_rate: 1.0000e-04
# Epoch 52/80
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9792 - loss: 0.0629 - precision: 0.9802 - recall: 0.9785
# Epoch 52: val_accuracy did not improve from 0.92049
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 212s 3s/step - accuracy: 0.9791 - loss: 0.0630 - precision: 0.9801 - recall: 0.9784 - val_accuracy: 0.9021 - val_loss: 0.3945 - val_precision: 0.9090 - val_recall: 0.9006 - learning_rate: 1.0000e-04
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 37.

# %%
runtime = end_time - start_time
print("Runtime:", runtime, "seconds")
hours = int(runtime / 3600)
minutes = int((runtime % 3600) / 60)
seconds = int(runtime % 60)

print("Total runtime:", hours, "hours,", minutes, "minutes,", seconds, "seconds")
# Out:
# Runtime: 9433.53801560402 seconds
# Total runtime: 2 hours, 37 minutes, 13 seconds

# %%
CNN_history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'precision', 'recall', 'val_accuracy', 'val_loss', 'val_precision', 'val_recall', 'learning_rate'])

# %%
tr_acc = CNN_history.history['accuracy']
tr_loss = CNN_history.history['loss']
tr_per = CNN_history.history['precision']
tr_recall = CNN_history.history['recall']
val_acc = CNN_history.history['val_accuracy']
val_loss = CNN_history.history['val_loss']
val_per = CNN_history.history['val_precision']
val_recall = CNN_history.history['val_recall']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
index_precision = np.argmax(val_per)
per_highest = val_per[index_precision]
index_recall = np.argmax(val_recall)
recall_highest = val_recall[index_recall]

Epochs = [i + 1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'
per_label = f'Best epoch = {str(index_precision + 1)}'
recall_label = f'Best epoch = {str(index_recall + 1)}'


plt.figure(figsize=(20, 12))
plt.style.use('fivethirtyeight')

plt.subplot(2, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training loss')
plt.plot(Epochs, val_loss, 'g', label='Validation loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(Epochs, tr_per, 'r', label='Precision')
plt.plot(Epochs, val_per, 'g', label='Validation Precision')
plt.scatter(index_precision + 1, per_highest, s=150, c='blue', label=per_label)
plt.title('Precision and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(Epochs, tr_recall, 'r', label='Recall')
plt.plot(Epochs, val_recall, 'g', label='Validation Recall')
plt.scatter(index_recall + 1, recall_highest, s=150, c='blue', label=recall_label)
plt.title('Recall and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.suptitle('Model Training Metrics Over Epochs', fontsize=16)
plt.show()

# %%
train_result = CNN_model.evaluate(X_train,Y_train)
print("Train Loss: {:.2f}%".format(train_result[0] * 100))
print("Train Accuracy: {:.2f}%".format(train_result[1] * 100))
print("Train Precision: {:.2f}%".format(train_result[2] * 100))
print("Train Recall: {:.2f}%".format(train_result[3] * 100))
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 37s 514ms/step - accuracy: 0.9690 - loss: 0.0931 - precision: 0.9712 - recall: 0.9626
# Train Loss: 9.15%
# Train Accuracy: 96.85%
# Train Precision: 97.13%
# Train Recall: 96.41%

# %%
test_results = CNN_model.evaluate(X_test,Y_test)

print("Test Loss: {:.2f}%".format(test_results[0] * 100))
print("Test Accuracy: {:.2f}%".format(test_results[1] * 100))
print("Test Precision: {:.2f}%".format(test_results[2] * 100))
print("Test Recall: {:.2f}%".format(test_results[3] * 100))
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - accuracy: 0.8761 - loss: 0.3185 - precision: 0.8852 - recall: 0.8734
# Test Loss: 30.28%
# Test Accuracy: 88.96%
# Test Precision: 89.75%
# Test Recall: 88.65%

# %%
predictions = CNN_model.predict(X_test)
y_true_test = np.argmax(Y_test, axis=1)
y_pred_test = np.argmax(predictions, axis=1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 512ms/step

# %%
accuracy = accuracy_score(y_true_test, y_pred_test)
print("Accuracy:{:.2f}%".format(accuracy * 100))
# Out:
# Accuracy:88.96%

# %%
plt.figure(figsize=(6, 4))
heatmap = sns.heatmap(confusion_matrix(y_true_test,y_pred_test), annot=True, fmt='3g',
                      xticklabels=classes, yticklabels=classes, annot_kws={"size": 8})

plt.title('Confusion Matrix',fontsize=8)
plt.xlabel('Predicted Label',fontsize=8)
plt.ylabel('True Label',fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %%
class_report = classification_report(y_true_test, y_pred_test, target_names=classes)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#                   precision    recall  f1-score   support
#
#         no_tumor       0.98      0.91      0.95        47
#  pituitary_tumor       0.93      0.96      0.94        96
# meningioma_tumor       0.88      0.89      0.88        94
#     glioma_tumor       0.91      0.89      0.90        89
#
#         accuracy                           0.91       326
#        macro avg       0.92      0.91      0.92       326
#     weighted avg       0.91      0.91      0.91       326

# %%
y_pred_prob = predictions
y_true_test_OneHot = np.array(tensorflow.keras.utils.to_categorical(y_true_test))

fpr = dict()
tpr = dict()
roc_auc = dict()

plt.figure(figsize=(6,4))
for i in range(len(classes)):
    fpr, tpr, _ = roc_curve(y_true_test_OneHot[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f}) for {classes[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate', fontsize=10)
plt.ylabel('True Positive Rate', fontsize=10)
plt.title('ROC Curve', fontsize=10)
plt.legend(loc='lower right', fontsize=10)
plt.show()

# %%
indices = np.random.choice(len(Y_test), size=12, replace=False)

images = X_test
Y_test = np.argmax(Y_test, axis=1)
labels = Y_test

plt.figure(figsize=(15, 15))

for i, idx in enumerate(indices):
    image = images[idx]
    true_label = classes[labels[idx]]


    prediction = CNN_model.predict(np.expand_dims(image, axis=0))
    predicted_class = classes[np.argmax(prediction)]
    confidence = np.max(prediction) * 100


    color = 'green' if true_label == predicted_class else 'red'


    plt.subplot(3, 4, i+1)
    plt.imshow(image)
    plt.title(f"Actual Class: {true_label}\nPredicted Class: {predicted_class}\nConfidence: {confidence:.2f}%", color=color, fontsize=14)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
plt.figure(figsize=(6, 6))
resized_img = cv2.resize(X_test[1], (shape[1], shape[0]))
img = np.asarray(resized_img)
img = np.expand_dims(img, axis=0)
img = cv2.normalize(img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
predictions = CNN_model.predict(img)
print('y_test : ',classes[Y_test[1]])
y_pred = np.argmax(predictions, axis=1)
print('y_pred : ',classes[y_pred[0]])
probs = list(predictions[0])
labels = classes
plt.subplot(2, 1, 1)
plt.imshow(resized_img)
plt.subplot(2, 1, 2)
bars = plt.barh(labels, probs)
plt.xlabel('Probability', fontsize=8)
ax = plt.gca()
ax.bar_label(bars, fmt = '%.2f')
plt.yticks(fontsize=10)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# y_test :  glioma_tumor
# y_pred :  glioma_tumor

# %%
CNN_model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
# Load the trained model
CNN_model = load_model('model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
